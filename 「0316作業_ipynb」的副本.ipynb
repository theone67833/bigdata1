# %% [markdown]
# <a href="https://colab.research.google.com/github/theone67833/bigdata1/blob/main/%E3%80%8C0316%E4%BD%9C%E6%A5%AD_ipynb%E3%80%8D%E7%9A%84%E5%89%AF%E6%9C%AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
library(readr)

# %%
dataset <- read.csv("11002.csv")

# %%
dataset
# Out:
#     歇業核准日期 統一編號 商業名稱
# 1   1100202       6373625 金積成行
# 2   1100225       6432461 利承工作所
# 3   1100201       6434974 虎山書苑
# 4   1100209       6547127 祥益汽材邦浦行
# 5   1100204       6601199 行益鐵材工作所
# 6   1100224       6605358 重光企業社
# 7   1100223       6647126 建文實業社
# 8   1100208       8438928 易昇實業社
# 9   1100208       8475227 壹成金企業社
# 10  1100224       9014080 仁和冷飲店
# 11  1100224       9091847 銀菱企業行
# 12  1100218       9097096 蒙地卡蘿烘焙坊
# 13  1100223      10112068 享達企業社
# 14  1100219      10128998 阿明鱔魚花枝
# 15  1100225      10157395 福和服裝行
# 16  1100218      10197354 欣喜來登企業社
# 17  1100205      10465745 億芳金香舖
# 18  1100218      10773617 永慶汽車輪胎行
# 19  1100223      10839625 登峰企業社
# 20  1100204      10848357 活力美芝城早餐永康勝利店
# 21  1100218      10869789 世真手工清潔用品坊
# 22  1100220      10873974 宇東商行
# 23  1100202      10877747 瑞山茶莊
# 24  1100224      10877850 天一漫畫租書店
# 25  1100201      13224257 國豐企業社
# 26  1100223      13224334 秀豐企業社
# 27  1100220      13585723 頂安香舖
# 28  1100201      14367794 建弘禮品社
# ...

# %%
head(dataset$商業名稱, n=6)
# Out:
# [1] "金積成行"       "利承工作所"     "虎山書苑"       "祥益汽材邦浦行"
# [5] "行益鐵材工作所" "重光企業社"

# %%
tail(dataset$商業名稱, n=6)
# Out:
# [1] "宜東商號"       "新禾汽車材料行" "連洲企業社"     "全益鈕釦行"
# [5] "五一冰茶"       "聯晟廣告企業社"

# %%
dataset[grepl("杜杜烘培",dataset$商業名稱),]
# Out:
#      歇業核准日期 統一編號 商業名稱 商業地址

# %%
歇業商店<- read.csv("11002.csv")
str(歇業商店)
# Out:
# 'data.frame':	183 obs. of  4 variables:
#  $ 歇業核准日期: int  1100202 1100225 1100201 1100209 1100204 1100224 1100223 1100208 1100208 1100224 ...
#  $ 統一編號    : int  6373625 6432461 6434974 6547127 6601199 6605358 6647126 8438928 8475227 9014080 ...
#  $ 商業名稱    : chr  "金積成行" "利承工作所" "虎山書苑" "祥益汽材邦浦行" ...
#  $ 商業地址    : chr  "臺南市中西區天后里西門路2段308號1樓" "臺南市北區安民里海安路3段32巷7號" "臺南市東區東門里慶東街103號1樓" "臺南市六甲區甲南里中正路244號" ...
